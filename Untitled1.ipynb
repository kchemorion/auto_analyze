# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Load data
df = pd.read_csv('robust_radiomcs.csv')
df.head()
# Out:
#     project_ID  level  wavelet.HH_gldm_SmallDependenceEmphasis  \
# 0  P0741_10000  L1_L2                                 0.000465
# 1  P0741_10000  L2_L3                                 0.001048
# 2  P0741_10000  L3_L4                                -0.000196
# 3  P0741_10000  L4_L5                                -0.000167
# 4  P0741_10000  L5_S1                                -0.004700
#
#    wavelet.LH_firstorder_10Percentile  \
# 0                           -2.774554
# 1                           -2.713167
# 2                           -3.029688
# 3                           -2.317023
# 4                           -2.826297
#
#    log.sigma.3.mm_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           0.381200
# 1                                           0.298655
# 2                                           0.317780
# 3                                           0.326686
# 4                                           0.743060
#
#    log.sigma.3.mm_glrlm_RunLengthNonUniformity  \
# 0                                    78.740286
# 1                                    56.800840
# 2                                    55.376551
# 3                                    69.573124
# 4                                   158.956563
#
#    log.sigma.1.mm_glrlm_LongRunEmphasis  \
# 0                             40.135234
# 1                             50.577658
# 2                             45.835855
# 3                             49.556678
# 4                             21.437950
#
#    original_glrlm_LongRunLowGrayLevelEmphasis  \
# 0                                    1.628114
# 1                                    2.610564
# 2                                    0.894079
# 3                                    2.147203
# 4                                    2.620817
#
#    log.sigma.3.mm_glrlm_ShortRunEmphasis  wavelet.LH_gldm_DependenceEntropy  \
# 0                               0.227772                           3.459829
# 1                               0.193180                           3.411992
# 2                               0.163922                           3.397677
# 3                               0.211783                           3.533925
# 4                               0.298350                           3.682501
#
#    ...  log.sigma.1.mm_glszm_LargeAreaEmphasis  \
# 0  ...                            47101.726538
# 1  ...                            81689.406782
# 2  ...                            82900.200878
# 3  ...                            72175.797697
# 4  ...                            16033.541327
#
#    log.sigma.5.mm_firstorder_10Percentile  original_glcm_JointAverage  \
# 0                               21.532686                    3.947168
# 1                               18.498249                    3.314613
# 2                                7.108029                    5.160897
# 3                               13.796311                    3.483116
# 4                               32.358131                    3.245690
#
#    log.sigma.5.mm_glcm_DifferenceAverage  \
# 0                               0.115918
# 1                               0.098385
# 2                               0.081871
# 3                               0.100777
# 4                               0.128559
#
#    log.sigma.3.mm_glszm_LargeAreaLowGrayLevelEmphasis  \
# 0                                       10727.361615
# 1                                       29822.390737
# 2                                       50139.063070
# 3                                       24521.999646
# 4                                        1840.383936
#
#    log.sigma.5.mm_glszm_GrayLevelNonUniformity  \
# 0                                     4.583528
# 1                                     3.193948
# 2                                     2.900694
# 3                                     5.667322
# 4                                     5.270930
#
#    wavelet.LH_glrlm_LongRunLowGrayLevelEmphasis  \
# 0                                     23.189007
# 1                                     26.855276
# 2                                     29.851483
# 3                                     14.782510
# 4                                      9.451790
#
#    log.sigma.1.mm_glrlm_RunPercentage  ivd_height_index  normalised_delta_si
# 0                            0.249186          0.250008             0.424563
# 1                            0.227145          0.259882             0.351916
# 2                            0.236976          0.306018             0.649820
# 3                            0.211682          0.221569             0.379049
# 4                            0.329058          0.136548             0.654302
#
# [5 rows x 205 columns]

# %% [markdown]
# ## Data Overview

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Load data
df = pd.read_csv('your_data.csv')
df.head()

# %% [markdown]
# ## Data Overview

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Load data
df = pd.read_csv('your_data.csv')
df.head()

# %% [markdown]
# ## Data Overview
